# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Daily_Water_Intake.csv")
data.head()
# Out:
#    Age  Gender  Weight (kg)  Daily Water Intake (liters)  \
# 0   56    Male           96                         4.23
# 1   60    Male          105                         3.95
# 2   36    Male           68                         2.39
# 3   19  Female           74                         3.13
# 4   38    Male           77                         2.11
#
#   Physical Activity Level Weather Hydration Level
# 0                Moderate     Hot            Good
# 1                    High  Normal            Good
# 2                Moderate    Cold            Good
# 3                Moderate     Hot            Good
# 4                     Low  Normal            Poor

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          30000 non-null  int64
#  1   Gender                       30000 non-null  object
#  2   Weight (kg)                  30000 non-null  int64
#  3   Daily Water Intake (liters)  30000 non-null  float64
#  4   Physical Activity Level      30000 non-null  object
#  5   Weather                      30000 non-null  object
#  6   Hydration Level              30000 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.6+ MB
#                 Age  Weight (kg)  Daily Water Intake (liters)
# count  30000.000000  30000.00000                 30000.000000
# mean      43.467667     76.84860                     2.852444
# std       14.998940     18.74494                     0.835537
# ...

# %%
sns.countplot(x='Hydration Level', data=data)
plt.show()

# %%
sns.boxplot(x='Hydration Level', y='Daily Water Intake (liters)', data=data)
plt.show()

# %%
data = data[['Age',
             'Weight (kg)',
             'Daily Water Intake (liters)',
             'Physical Activity Level',
             'Weather',
             'Hydration Level']]

# %%
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#    Age  Weight (kg)  Daily Water Intake (liters)  Physical Activity Level_Low  \
# 0   56           96                         4.23                        False
# 1   60          105                         3.95                        False
# 2   36           68                         2.39                        False
# 3   19           74                         3.13                        False
# 4   38           77                         2.11                         True
#
#    Physical Activity Level_Moderate  Weather_Hot  Weather_Normal  \
# 0                              True         True           False
# 1                             False        False            True
# 2                              True        False           False
# 3                              True         True           False
# 4                             False        False            True
#
#    Hydration Level_Poor
# 0                 False
# 1                 False
# 2                 False
# ...

# %%
data['Hydration Level_Poor'].value_counts()
# Out:
# Hydration Level_Poor
# False    23915
# True      6085
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = data.drop('Hydration Level_Poor', axis=1)
y = data['Hydration Level_Poor']

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test)

accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.99      4788
#         True       0.98      0.93      0.95      1212
#
#     accuracy                           0.98      6000
#    macro avg       0.98      0.96      0.97      6000
# weighted avg       0.98      0.98      0.98      6000

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()

# %%
import joblib
joblib.dump(model, "hydration_model.pkl")
# Out:
# ['hydration_model.pkl']
