# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('heart_2020_cleaned.csv')

# %%
df['BMI'].mean()
# Out:
# np.float64(28.32539852092747)

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# No     292422
# Yes     27373
# Name: count, dtype: int64

# %%
df['BMI'].max(), df['BMI'].min()
# Out:
# (np.float64(94.85), np.float64(12.02))

# %%
(df['BMI'] > 30).sum()
# Out:
# np.int64(102548)

# %%
df[(df['PhysicalActivity'] == 'No') & (df['HeartDisease'] == 'Yes')].shape[0]
# Out:
# 9884

# %%
plt.hist(df['BMI'], bins=10)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('BMI Distribution')
plt.show()

# %%
df.groupby('PhysicalActivity')['HeartDisease'] \
  .value_counts(normalize=True)
# Out:
# PhysicalActivity  HeartDisease
# No                No              0.862413
#                   Yes             0.137587
# Yes               No              0.929468
#                   Yes             0.070532
# Name: proportion, dtype: float64

# %%
df['Smoking'].value_counts().plot(
    kind='pie', autopct='%1.1f%%'
)
plt.ylabel('')
plt.title('Smoking Status Distribution')
plt.show()

# %%
df['Smoking'].value_counts(normalize=True) * 100
# Out:
# Smoking
# No     58.752326
# Yes    41.247674
# Name: proportion, dtype: float64

# %%
plt.scatter(df['BMI'], df['SleepTime'])
plt.xlabel('BMI')
plt.ylabel('Sleep Time')
plt.title('BMI vs Sleep Time')
plt.show()

# %%
df.boxplot(column='SleepTime')
plt.title('Sleep Time Distribution')
plt.show()

# %%
df['SleepTime'].median()
# Out:
# np.float64(7.0)
